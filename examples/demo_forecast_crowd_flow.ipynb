# %% [markdown]
# # STEN Forecasting demo
#
# In this notebook, we will:
# 1. **Load data**: Load pytorch geometric temporal data and split into torch train test val dataloaders.
# 2. **Model Building**: We will build and train a STEN model - the DenseGCNGRU model using the processed data.
# 3. **Model Evaluation**: We will print and plot model outputs to look at its performance.

# %%
# import all the necessary libraries
import os
import torch

# for relative imports
os.chdir('..') 
print(os.getcwd()) # should print /your_local_dir/crowd-framework

# cuda or cpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# c:\Users\haryd\crowd-framework
# cuda

# %%
class Args:
    def __init__(self):
        self.DATASET = 'GCS'
        self.forecasting_horizon = 20
        self.train_ratio = 0.7
        self.test_ratio = 0.3
        self.val_ratio = 0.0
        self.batch_size = 32
        self.lr = 0.001
        self.epochs = 40
        self.save_model = False
        self.save_dir = './checkpoints'
args = Args()

# %% [markdown]
# ## 1. Load data. this step is the same as one shown in demo_dataset.ipynb.

# %%
from st_dif.data_utils import get_pyg_temporal_dataset, get_loaders
# get pytorch dataloaders
dataset, _ = get_pyg_temporal_dataset(args.DATASET, args.forecasting_horizon)
train_loader, val_loader, test_loader = get_loaders(dataset, 
                                                    args.batch_size, 
                                                    args.train_ratio, 
                                                    args.val_ratio, 
                                                    args.test_ratio, 
                                                    device)
# Out:
# Dataset type:   <torch_geometric_temporal.signal.static_graph_temporal_signal.StaticGraphTemporalSignal object at 0x0000012914458BE0>
# Number of samples / sequences:  2356
# Data(x=[6, 2, 20], edge_index=[2, 10], edge_attr=[10], y=[6, 20])
# Number of train buckets:  1649
# Number of val buckets:  0
# Number of test buckets:  707

# %% [markdown]
# In order to run a graph neural network, the inputs are $A$, the adjacency matrix, and $X$, the node feature matrix. Since our $A$ is defined by inter-PAR connections and is assumed to never change, we can reduce computational time by only loading $A$ once. In PyTorch Geometric, $A$ is represented as the edge_index object.

# %%
# get static edge index (i.e. adjacency matrix). Only need to do this one since edge index doesn't change for each CMGraph. 
for snapshot in dataset:
    static_edge_index = snapshot.edge_index.to(device)
    break;
# Edge indices (represents adjacency matrix/PAR connections) of the CMGraphs. 
print(static_edge_index)
# Out:
# tensor([[0, 1, 1, 2, 2, 3, 3, 4, 4, 5],
#         [1, 0, 2, 1, 3, 2, 4, 3, 5, 4]], device='cuda:0')

# %% [markdown]
# ## 2. Set up and Train a STEN Model

# %% [markdown]
# STEN stands for spatio-temporal encoder network. It is a framework for crowd flow forecasting that involves spatially connected pedestrian activity regions (PARs). In this repo we have provided two STEN models for easy plug in and play. We'll use the best performing mode, Dense-GCN-GRU here. The model can simply be called from our STEN model zoo.

# %%
from st_dif.models import DenseGCNGRU
model = DenseGCNGRU(in_channels=2, 
                    periods=args.forecasting_horizon, 
                    batch_size=args.batch_size).to(device) 
print(model)
# Out:
# DenseGCNGRU(
#   (densegcn): DeepGCNLayer(block=dense)
#   (gru): GRU(130, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=20, bias=True)
# )

# %% [markdown]
# To train the model
# with the data, we can use the train function from campuscrowd.train_test_utils. This function trains the model and return the model checkpoint. Inside train(), there is a training loop that essentially computes loss and does backprop based on the model-generated prediction vector y_hat. y_hat is computed in the following code snippet:
# ```python
#  for encoder_inputs, labels in train_loader:
#     y_hat = model(encoder_inputs, static_edge_index)
#     # torch.tensor storing model predictions. Full training loop omitted for conciseness.
# ```

# %%
from st_dif.train_test_utils import train
# train model
model, checkpoint_dict = train( model, 
                                train_loader, 
                                val_loader, 
                                static_edge_index, 
                                num_epochs=args.epochs, lr=args.lr
                                )
# Out:
# Epoch 0 Step 0 train MSE: 0.9757
# Epoch 0 Average Training MSE: 0.3088
# Epoch 1 Step 0 train MSE: 0.0554
# Epoch 1 Average Training MSE: 0.0467
# Epoch 2 Step 0 train MSE: 0.0399
# Epoch 2 Average Training MSE: 0.0415
# Epoch 3 Step 0 train MSE: 0.0446
# Epoch 3 Average Training MSE: 0.0411
# Epoch 4 Step 0 train MSE: 0.0430
# Epoch 4 Average Training MSE: 0.0402
# Epoch 5 Step 0 train MSE: 0.0464
# Epoch 5 Average Training MSE: 0.0390
# Epoch 6 Step 0 train MSE: 0.0369
# Epoch 6 Average Training MSE: 0.0389
# Epoch 7 Step 0 train MSE: 0.0415
# Epoch 7 Average Training MSE: 0.0382
# Epoch 8 Step 0 train MSE: 0.0367
# Epoch 8 Average Training MSE: 0.0384
# Epoch 9 Step 0 train MSE: 0.0405
# Epoch 9 Average Training MSE: 0.0374
# Epoch 10 Step 0 train MSE: 0.0357
# Epoch 10 Average Training MSE: 0.0372
# Epoch 11 Step 0 train MSE: 0.0374
# Epoch 11 Average Training MSE: 0.0368
# Epoch 12 Step 0 train MSE: 0.0405
# Epoch 12 Average Training MSE: 0.0368
# Epoch 13 Step 0 train MSE: 0.0323
# Epoch 13 Average Training MSE: 0.0368
# Epoch 14 Step 0 train MSE: 0.0423
# Epoch 14 Average Training MSE: 0.0368
# Epoch 15 Step 0 train MSE: 0.0300
# Epoch 15 Average Training MSE: 0.0367
# Epoch 16 Step 0 train MSE: 0.0374
# Epoch 16 Average Training MSE: 0.0362
# Epoch 17 Step 0 train MSE: 0.0308
# Epoch 17 Average Training MSE: 0.0362
# Epoch 18 Step 0 train MSE: 0.0330
# Epoch 18 Average Training MSE: 0.0360
# Epoch 19 Step 0 train MSE: 0.0392
# Epoch 19 Average Training MSE: 0.0359
# Epoch 20 Step 0 train MSE: 0.0326
# Epoch 20 Average Training MSE: 0.0365
# Epoch 21 Step 0 train MSE: 0.0291
# Epoch 21 Average Training MSE: 0.0359
# Epoch 22 Step 0 train MSE: 0.0375
# Epoch 22 Average Training MSE: 0.0356
# Epoch 23 Step 0 train MSE: 0.0413
# Epoch 23 Average Training MSE: 0.0358
# Epoch 24 Step 0 train MSE: 0.0342
# Epoch 24 Average Training MSE: 0.0357
# Epoch 25 Step 0 train MSE: 0.0367
# Epoch 25 Average Training MSE: 0.0353
# Epoch 26 Step 0 train MSE: 0.0327
# Epoch 26 Average Training MSE: 0.0352
# Epoch 27 Step 0 train MSE: 0.0388
# Epoch 27 Average Training MSE: 0.0349
# Epoch 28 Step 0 train MSE: 0.0348
# Epoch 28 Average Training MSE: 0.0350
# Epoch 29 Step 0 train MSE: 0.0308
# Epoch 29 Average Training MSE: 0.0349
# Epoch 30 Step 0 train MSE: 0.0377
# Epoch 30 Average Training MSE: 0.0352
# Epoch 31 Step 0 train MSE: 0.0334
# Epoch 31 Average Training MSE: 0.0349
# Epoch 32 Step 0 train MSE: 0.0357
# Epoch 32 Average Training MSE: 0.0346
# Epoch 33 Step 0 train MSE: 0.0323
# Epoch 33 Average Training MSE: 0.0344
# Epoch 34 Step 0 train MSE: 0.0304
# Epoch 34 Average Training MSE: 0.0341
# Epoch 35 Step 0 train MSE: 0.0311
# Epoch 35 Average Training MSE: 0.0339
# Epoch 36 Step 0 train MSE: 0.0312
# Epoch 36 Average Training MSE: 0.0342
# Epoch 37 Step 0 train MSE: 0.0375
# Epoch 37 Average Training MSE: 0.0339
# Epoch 38 Step 0 train MSE: 0.0330
# Epoch 38 Average Training MSE: 0.0336
# Epoch 39 Step 0 train MSE: 0.0349
# Epoch 39 Average Training MSE: 0.0337

# %% [markdown]
# You can save the model checkpoint if you want

# %%
from st_dif import save_or_update_checkpoint
 # save model if needed
if args.save_model:
    filename = model.__class__.__name__+'_'+args.DATASET+'_'+'{}_steps'.format(args.forecasting_horizon)+'.pt'
    path = os.path.join(args.save_dir,
                        filename)
    save_or_update_checkpoint(checkpoint_dict, path)

# %% [markdown]
# ## 3. Evaluate MSE of Prediction

# %% [markdown]
# Similar to train(), evaluation can be done with the evaluate() function.
# It computes MSE and update it in checkpoint_dict

# %%
from st_dif import evaluate
model, checkpoint_dict = evaluate(model, test_loader, static_edge_index, checkpoint_dict=checkpoint_dict)
# Out:
# Test MSE: 0.0332
# Test MAE: 0.1287
