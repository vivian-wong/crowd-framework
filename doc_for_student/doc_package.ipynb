# %% [markdown]
# # Package Walkthrough
# The package should be called 'ST-DIF Crowd' (for now), name still under considerations and I welcome any suggestions... It should cleanly wrap all functionalities of the codes, including load dataset, loading crowd forecasting models, and running experiments to validate results. Of course, as a package, people should be able to easily install it.
#
# The name ST-DIF comes from the temporary name of the paper I plan to write, "ST-DIF: A spatio-temporal data integration framework to estimate pedestrian crowd flow from multi-camera surveillance in built environments"

# %% [markdown]
# ## To Install
# User should be able to easily install the whole pacakge using:
# ```
# pip install stdif
# ```
# This command should automatically install the entire package as well as all dependencies. If there are a few dependencies that cannot be installed this way, please keep track of additional dependencies that user need to additionally install prior to running the above command in the github repo's README.md file. To keep the package easily accessible and convenient, the number of additional packages to be installed with separate commands should be minimal (i.e. try to have most of the environment set up with just pip install stdif)
#
#
# Note that stdif is just a placeholder that I've used in my codes... But as I am writing this, I was thinking maybe putting the word 'crowd' in there would be nicer, so maybe 'stdif-crowd' instead? However, this means that you'll also have to change the imports in main.py which is used in the next step. Anyways, just make sure we have the flexibility to modify the package import name in the future?

# %% [markdown]
# ## To do everything else & validate that it works
# Now, with just the package installed, one should be able to run any python file that imports data, model, etc. from stdif.
#
# For example, you should be able to copy just the github repo's 'experiment' folder (make sure you're NOT copying any other folders, otherwise the import might end up coming from your local files rather than the pip installed package), to your local computer. and run
# ```
# bash reproduce_paper_experiments.sh
# ```
# and it should just run!

# %% [markdown]
# # Final Report

# %% [markdown]
# Finally, once this is all done, for your final report, I hope to see a markdown file that goes through what you've set up, and I think it could also just serve as the README.md file that a user who's never used the package can follow. For example, this one: https://github.com/yzhao062/pyod. If you check out it's README, it's got
# Table of Contents:
#
# Installation
# API Cheatsheet & Reference
# ADBench Benchmark and Datasets
# Model Save & Load
# Fast Train with SUOD
# Thresholding Outlier Scores
# Implemented Algorithms
# Quick Start for Outlier Detection
# How to Contribute
# Inclusion Criteria
#
# If you could edit the current README to look like this for the github repo, it would would be sufficient for the final report.

# %% [markdown]
# # Final Code
# Lastly, please make sure you push all your commits to a separate branch so that I can check and merge.
